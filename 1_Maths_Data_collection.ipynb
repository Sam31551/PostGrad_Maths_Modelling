# %% [markdown]
# This analysis will centre around the 24 teams in the 2024 UEFA European Football Championships. Data will be collected from a variety of sources all of which may have a role in influencing a nation's odds of winning. This data will be merged to create one coherent dataset.

# %% [markdown]
# # World ranking

# %% [markdown]
# The first metric that could help predict a nation's chance of winning the tournament is their world ranking. This is a metric that ranks each of the countries based on their previous sporting performance. This data is scraped from an online source.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the webpage
url = "https://www.sportingnews.com/uk/football/news/fifa-rankings-euro-2024-teams-soccer-uefa-euro-championship/880ff126e23e0e4833ce8e08"

# Fetch the webpage content
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Extract the table data
table_data = []
table = soup.find('table')

for row in table.find_all('tr'):
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    if cols:
        table_data.append(cols)

# Create a DataFrame
df = pd.DataFrame(table_data, columns=['Team', 'FIFA Rank'])

# Drop the first row
df = df.drop(0)

# Sort table alphabetically by Team
df_sorted = df.sort_values(by='Team')

#Rename Czechia for consistency across datasets
df_sorted['Team'] = df_sorted['Team'].replace('Czechia', 'Czech Republic')

# Reset index after dropping rows and rearranging order
df_sorted.reset_index(drop=True, inplace=True)
df_sorted
# Out:
#               Team FIFA Rank
# 0          Albania        66
# 1          Austria        25
# 2          Belgium         3
# 3          Croatia        10
# 4   Czech Republic        36
# 5          Denmark        21
# 6          England         4
# 7           France         2
# 8          Georgia        75
# 9          Germany        16
# 10         Hungary        26
# 11           Italy         9
# 12     Netherlands         7
# 13          Poland        28
# 14        Portugal         6
# 15         Romania        46
# 16        Scotland        39
# 17          Serbia        33
# 18        Slovakia        48
# 19        Slovenia        57
# 20           Spain         8
# 21     Switzerland        19
# 22          Turkey        40
# 23         Ukraine        22

# %% [markdown]
# #Manager Data

# %% [markdown]
# Each football team has a manager who are responsible for picking players and organising them into a coherent team. Their experience and time in charge may be meaningful metrics when it comes to tournament odds.

# %% [markdown]
# **Note:** Managers with ? in the 'Contract until' column, did not have this information stored in the online dataset. This will be resolved later in the analysis.

# %%
#Copied and pasted into excel from https://www.transfermarkt.co.uk/europameisterschaft-2024/trainer/pokalwettbewerb/EM24
managers = pd.read_csv('Managers.csv', encoding = 'ISO-8859-1')
managers
# Out:
#               Manager         Country  Age                Installation  \
# 0    Didier Deschamps          France   55  11 years 11 months 04 days
# 1    Gareth Southgate         England   53  07 years 08 months 15 days
# 2        Zlatko Dalic         Croatia   57  06 years 08 months 05 days
# 3         Marco Rossi         Hungary   59  05 years 11 months 24 days
# 4          Matjaz Kek        Slovenia   62  05 years 06 months 16 days
# 5        Steve Clarke        Scotland   60            05 years 23 days
# 6     Kasper Hjulmand         Denmark   52  03 years 10 months 11 days
# 7        Willy Sagnol         Georgia   47  03 years 03 months 28 days
# 8    Dragan Stojkovic          Serbia   59  03 years 03 months 09 days
# 9         Murat Yakin     Switzerland   49  02 years 10 months 03 days
# 10  Edward Iord?nescu         Romania   45  02 years 04 months 17 days
# 11      Ralf Rangnick         Austria   65            02 years 11 days
# 12  Francesco Calzona        Slovakia   55   01 year 11 months 03 days
# 13      Ronald Koeman     Netherlands   61   01 year 05 months 11 days
# 14  Luis de la Fuente           Spain   62   01 year 05 months 11 days
# 15           Sylvinho         Albania   50   01 year 05 months 10 days
# 16   Roberto Martínez        Portugal   50   01 year 05 months 03 days
# 17   Domenico Tedesco         Belgium   38   01 year 04 months 04 days
# 18      Sergiy Rebrov         Ukraine   50             01 year 05 days
# 19  Luciano Spalletti           Italy   65           09 months 11 days
# 20    Michal Probierz          Poland   51           08 months 23 days
# 21  Vincenzo Montella         Türkiye   49           08 months 22 days
# 22  Julian Nagelsmann         Germany   36           08 months 21 days
# 23         Ivan Hasek  Czech Republic   60           05 months 08 days
#
#    Contract until
# 0            2026
# 1            2024
# 2            2026
# 3            2025
# 4            2025
# 5            2026
# 6            2026
# 7            2024
# 8               ?
# 9            2024
# 10           2024
# 11           2025
# 12           2025
# 13           2026
# 14           2026
# 15           2024
# 16           2026
# 17           2026
# 18           2026
# 19           2026
# 20              ?
# 21           2026
# 22           2026
# 23           2025

# %% [markdown]
# These managers are sorted by the country they managed and the dataset index is reset.

# %%
# Sort table alphabetically by Team
managers_sorted = managers.sort_values(by='Country')
# Reset index after dropping rows and rearranging order
managers_sorted.reset_index(drop=True, inplace=True)
managers_sorted
# Out:
#               Manager         Country  Age                Installation  \
# 0            Sylvinho         Albania   50   01 year 05 months 10 days
# 1       Ralf Rangnick         Austria   65            02 years 11 days
# 2    Domenico Tedesco         Belgium   38   01 year 04 months 04 days
# 3        Zlatko Dalic         Croatia   57  06 years 08 months 05 days
# 4          Ivan Hasek  Czech Republic   60           05 months 08 days
# 5     Kasper Hjulmand         Denmark   52  03 years 10 months 11 days
# 6    Gareth Southgate         England   53  07 years 08 months 15 days
# 7    Didier Deschamps          France   55  11 years 11 months 04 days
# 8        Willy Sagnol         Georgia   47  03 years 03 months 28 days
# 9   Julian Nagelsmann         Germany   36           08 months 21 days
# 10        Marco Rossi         Hungary   59  05 years 11 months 24 days
# 11  Luciano Spalletti           Italy   65           09 months 11 days
# 12      Ronald Koeman     Netherlands   61   01 year 05 months 11 days
# 13    Michal Probierz          Poland   51           08 months 23 days
# 14   Roberto Martínez        Portugal   50   01 year 05 months 03 days
# 15  Edward Iord?nescu         Romania   45  02 years 04 months 17 days
# 16       Steve Clarke        Scotland   60            05 years 23 days
# 17   Dragan Stojkovic          Serbia   59  03 years 03 months 09 days
# 18  Francesco Calzona        Slovakia   55   01 year 11 months 03 days
# 19         Matjaz Kek        Slovenia   62  05 years 06 months 16 days
# 20  Luis de la Fuente           Spain   62   01 year 05 months 11 days
# 21        Murat Yakin     Switzerland   49  02 years 10 months 03 days
# 22  Vincenzo Montella         Türkiye   49           08 months 22 days
# 23      Sergiy Rebrov         Ukraine   50             01 year 05 days
#
#    Contract until
# 0            2024
# 1            2025
# 2            2026
# 3            2026
# 4            2025
# 5            2026
# 6            2024
# 7            2026
# 8            2024
# 9            2026
# 10           2025
# 11           2026
# 12           2026
# 13              ?
# 14           2026
# 15           2024
# 16           2026
# 17              ?
# 18           2025
# 19           2025
# 20           2026
# 21           2024
# 22           2026
# 23           2026

# %% [markdown]
# Age is renamed as manager age to avoid confusion with player age when data is merged later in the analysis.

# %%
managers_sorted = managers_sorted.rename(columns={'Age': 'Manager_Age'})
managers_sorted.head(3)
# Out:
#             Manager  Country  Manager_Age               Installation  \
# 0          Sylvinho  Albania           50  01 year 05 months 10 days
# 1     Ralf Rangnick  Austria           65           02 years 11 days
# 2  Domenico Tedesco  Belgium           38  01 year 04 months 04 days
#
#   Contract until
# 0           2024
# 1           2025
# 2           2026

# %%
managers_sorted = managers_sorted.rename(columns={'Country': 'Team'})
managers_sorted.head(3)
# Out:
#             Manager     Team  Manager_Age               Installation  \
# 0          Sylvinho  Albania           50  01 year 05 months 10 days
# 1     Ralf Rangnick  Austria           65           02 years 11 days
# 2  Domenico Tedesco  Belgium           38  01 year 04 months 04 days
#
#   Contract until
# 0           2024
# 1           2025
# 2           2026

# %%
managers_sorted
# Out:
#               Manager            Team  Manager_Age  \
# 0            Sylvinho         Albania           50
# 1       Ralf Rangnick         Austria           65
# 2    Domenico Tedesco         Belgium           38
# 3        Zlatko Dalic         Croatia           57
# 4          Ivan Hasek  Czech Republic           60
# 5     Kasper Hjulmand         Denmark           52
# 6    Gareth Southgate         England           53
# 7    Didier Deschamps          France           55
# 8        Willy Sagnol         Georgia           47
# 9   Julian Nagelsmann         Germany           36
# 10        Marco Rossi         Hungary           59
# 11  Luciano Spalletti           Italy           65
# 12      Ronald Koeman     Netherlands           61
# 13    Michal Probierz          Poland           51
# 14   Roberto Martínez        Portugal           50
# 15  Edward Iord?nescu         Romania           45
# 16       Steve Clarke        Scotland           60
# 17   Dragan Stojkovic          Serbia           59
# 18  Francesco Calzona        Slovakia           55
# 19         Matjaz Kek        Slovenia           62
# 20  Luis de la Fuente           Spain           62
# 21        Murat Yakin     Switzerland           49
# 22  Vincenzo Montella         Türkiye           49
# 23      Sergiy Rebrov         Ukraine           50
#
#                   Installation Contract until
# 0    01 year 05 months 10 days           2024
# 1             02 years 11 days           2025
# 2    01 year 04 months 04 days           2026
# 3   06 years 08 months 05 days           2026
# 4            05 months 08 days           2025
# 5   03 years 10 months 11 days           2026
# 6   07 years 08 months 15 days           2024
# 7   11 years 11 months 04 days           2026
# 8   03 years 03 months 28 days           2024
# 9            08 months 21 days           2026
# 10  05 years 11 months 24 days           2025
# 11           09 months 11 days           2026
# 12   01 year 05 months 11 days           2026
# 13           08 months 23 days              ?
# 14   01 year 05 months 03 days           2026
# 15  02 years 04 months 17 days           2024
# 16            05 years 23 days           2026
# 17  03 years 03 months 09 days              ?
# 18   01 year 11 months 03 days           2025
# 19  05 years 06 months 16 days           2025
# 20   01 year 05 months 11 days           2026
# 21  02 years 10 months 03 days           2024
# 22           08 months 22 days           2026
# 23             01 year 05 days           2026

# %%
managers_sorted['Team'] = managers_sorted['Team'].replace('Türkiye', 'Turkey')

# %% [markdown]
# #Players

# %% [markdown]
# Each nation's squad is made up of a group of generally 20-25 players. Personal data such as name, position, age etc tell us generic information about the player. The number of caps/goals each player has as well as their 'Market Value' could be considered to be more indicative of the players' sporting quality and experience.

# %%
#Data downloaded from https://www.kaggle.com/datasets/damirdizdarevic/uefa-euro-2024-players
players = pd.read_csv('euro2024_players.csv', encoding = 'ISO-8859-1')
players
# Out:
#                        Name        Position  Age                 Club  Height  \
# 0    Marc-AndrÃ© ter Stegen      Goalkeeper   32         FC Barcelona     187
# 1              Manuel Neuer      Goalkeeper   38        Bayern Munich     193
# 2            Oliver Baumann      Goalkeeper   34  TSG 1899 Hoffenheim     187
# 3        Nico Schlotterbeck     Centre-Back   24    Borussia Dortmund     191
# 4              Jonathan Tah     Centre-Back   28  Bayer 04 Leverkusen     195
# ..                      ...             ...  ...                  ...     ...
# 618             Adam Hlozek  Second Striker   21  Bayer 04 Leverkusen     188
# 619           Patrik Schick  Centre-Forward   28  Bayer 04 Leverkusen     191
# 620          MojmÃ­r Chytil  Centre-Forward   25     SK Slavia Prague     187
# 621              Jan Kuchta  Centre-Forward   27     AC Sparta Prague     185
# 622             Tomas Chory  Centre-Forward   29    FC Viktoria Plzen     199
#
#       Foot  Caps  Goals  MarketValue         Country
# 0    right    40      0     28000000         Germany
# 1    right   119      0      4000000         Germany
# 2    right     0      0      3000000         Germany
# 3     left    12      0     40000000         Germany
# 4    right    25      0     30000000         Germany
# ..     ...   ...    ...          ...             ...
# 618  right    31      2     12000000  Czech Republic
# 619   left    37     18     22000000  Czech Republic
# 620      -    12      4      6500000  Czech Republic
# 621  right    20      3      5000000  Czech Republic
# 622  right     3      2      3200000  Czech Republic
#
# [623 rows x 10 columns]

# %% [markdown]
# These players are sorted by the country the play for and the index is updated.

# %%
# Sort table alphabetically by Country
players_sorted = players.sort_values(by='Country')
# Reset index after dropping rows and rearranging order
players_sorted.reset_index(drop=True, inplace=True)
players_sorted
# Out:
#                   Name      Position  Age              Club  Height   Foot  \
# 0       Elhan Kastrati    Goalkeeper   27     AS Cittadella     189  right
# 1     Thomas Strakosha    Goalkeeper   29      Brentford FC     193  right
# 2        Etrit Berisha    Goalkeeper   35         FC Empoli     194   left
# 3       Berat Djimsiti   Centre-Back   31       Atalanta BC     190  right
# 4      Marash Kumbulla   Centre-Back   24       US Sassuolo     191  right
# ..                 ...           ...  ...               ...     ...    ...
# 618   Mykola Matvienko   Centre-Back   28  Shakhtar Donetsk     182   left
# 619      Ilya Zabarnyi   Centre-Back   21   AFC Bournemouth     189  right
# 620   Georgiy Bushchan    Goalkeeper   30       Dynamo Kyiv     196  right
# 621  Oleksandr Tymchyk    Right-Back   27       Dynamo Kyiv     180  right
# 622  Andriy Yarmolenko  Right Winger   34       Dynamo Kyiv     189   left
#
#      Caps  Goals  MarketValue  Country
# 0       2      0      1300000  Albania
# 1      28      0      3000000  Albania
# 2      80      0       500000  Albania
# 3      57      1     10000000  Albania
# 4      19      0      4500000  Albania
# ..    ...    ...          ...      ...
# 618    64      0     18000000  Ukraine
# 619    35      1     32000000  Ukraine
# 620    18      0      7000000  Ukraine
# 621    17      1      4000000  Ukraine
# 622   118     46      2000000  Ukraine
#
# [623 rows x 10 columns]

# %%
player_metrics = players_sorted[['Age', 'Height', 'Caps', 'Goals', 'MarketValue', 'Country']]
player_metrics
# Out:
#      Age  Height  Caps  Goals  MarketValue  Country
# 0     27     189     2      0      1300000  Albania
# 1     29     193    28      0      3000000  Albania
# 2     35     194    80      0       500000  Albania
# 3     31     190    57      1     10000000  Albania
# 4     24     191    19      0      4500000  Albania
# ..   ...     ...   ...    ...          ...      ...
# 618   28     182    64      0     18000000  Ukraine
# 619   21     189    35      1     32000000  Ukraine
# 620   30     196    18      0      7000000  Ukraine
# 621   27     180    17      1      4000000  Ukraine
# 622   34     189   118     46      2000000  Ukraine
#
# [623 rows x 6 columns]

# %% [markdown]
# Grouping the players by country will allow for easy comparison between countries about the key metrics when it comes to the playing squad. 'Grouping' the players by country means gathering players into their respective countries and then calculating the mean (of each numeric metric) of each player per country.

# %% [markdown]
# This leaves the dataset as one row per country with the metrics representing the average value for the players in that squad.

# %%
players_grouped = player_metrics.groupby('Country').mean().reset_index()
players_grouped
# Out:
#            Country        Age      Height       Caps     Goals   MarketValue
# 0          Albania  27.307692  183.615385  26.115385  1.538462  4.292308e+06
# 1          Austria  26.807692  183.192308  23.576923  3.576923  9.057692e+06
# 2          Belgium  26.880000  184.680000  37.960000  7.080000  2.338000e+07
# 3          Croatia  27.692308  184.115385  44.307692  5.653846  1.260385e+07
# 4   Czech Republic  25.307692  185.538462  15.576923  2.500000  7.457692e+06
# 5          Denmark  27.692308  186.269231  41.192308  5.192308  1.598077e+07
# 6          England  26.076923  182.461538  25.038462  3.846154  5.826923e+07
# 7           France  26.880000  184.440000  33.440000  7.680000  4.936000e+07
# 8          Georgia  27.153846  184.500000  28.846154  2.461538  6.159615e+06
# 9          Germany  28.115385  185.384615  34.846154  5.153846  3.273077e+07
# 10         Hungary  27.423077  182.807692  28.846154  2.307692  6.325000e+06
# 11           Italy  26.500000  184.346154  20.346154  2.269231  2.713462e+07
# 12     Netherlands  26.538462  185.192308  32.230769  5.423077  3.250000e+07
# 13          Poland  27.555556  184.814815  30.555556  5.703704  7.866667e+06
# 14        Portugal  26.961538  182.384615  42.807692  8.653846  4.055769e+07
# 15         Romania  27.000000  183.846154  22.692308  2.423077  3.543269e+06
# 16        Scotland  28.230769  182.692308  24.730769  2.269231  7.976923e+06
# 17          Serbia  27.384615  186.769231  33.076923  4.961538  1.199231e+07
# 18        Slovakia  27.269231  184.423077  33.153846  2.576923  6.026923e+06
# 19        Slovenia  27.346154  184.923077  29.653846  3.000000  5.365385e+06
# 20           Spain  26.961538  181.769231  20.576923  3.653846  3.713462e+07
# 21     Switzerland  27.692308  183.923077  42.000000  4.807692  1.084615e+07
# 22         Turkiye  25.807692  183.923077  24.307692  2.730769  1.246538e+07
# 23         Ukraine  26.346154  184.346154  32.653846  4.384615  1.457692e+07

# %%
players_grouped = players_grouped.rename(columns={'Country': 'Team'})
players_grouped.head(3)
# Out:
#       Team        Age      Height       Caps     Goals   MarketValue
# 0  Albania  27.307692  183.615385  26.115385  1.538462  4.292308e+06
# 1  Austria  26.807692  183.192308  23.576923  3.576923  9.057692e+06
# 2  Belgium  26.880000  184.680000  37.960000  7.080000  2.338000e+07

# %%
# Replace 'Turkiye' with 'Turkey' in the 'Team' column
players_grouped['Team'] = players_grouped['Team'].replace('Turkiye', 'Turkey')

# %%
# Convert 'MarketValue' column from scientific notation to numeric
players_grouped['MarketValue'] = players_grouped['MarketValue'].apply(lambda x: '{:.0f}'.format(x))

players_grouped
# Out:
#               Team        Age      Height       Caps     Goals MarketValue
# 0          Albania  27.307692  183.615385  26.115385  1.538462     4292308
# 1          Austria  26.807692  183.192308  23.576923  3.576923     9057692
# 2          Belgium  26.880000  184.680000  37.960000  7.080000    23380000
# 3          Croatia  27.692308  184.115385  44.307692  5.653846    12603846
# 4   Czech Republic  25.307692  185.538462  15.576923  2.500000     7457692
# 5          Denmark  27.692308  186.269231  41.192308  5.192308    15980769
# 6          England  26.076923  182.461538  25.038462  3.846154    58269231
# 7           France  26.880000  184.440000  33.440000  7.680000    49360000
# 8          Georgia  27.153846  184.500000  28.846154  2.461538     6159615
# 9          Germany  28.115385  185.384615  34.846154  5.153846    32730769
# 10         Hungary  27.423077  182.807692  28.846154  2.307692     6325000
# 11           Italy  26.500000  184.346154  20.346154  2.269231    27134615
# 12     Netherlands  26.538462  185.192308  32.230769  5.423077    32500000
# 13          Poland  27.555556  184.814815  30.555556  5.703704     7866667
# 14        Portugal  26.961538  182.384615  42.807692  8.653846    40557692
# 15         Romania  27.000000  183.846154  22.692308  2.423077     3543269
# 16        Scotland  28.230769  182.692308  24.730769  2.269231     7976923
# 17          Serbia  27.384615  186.769231  33.076923  4.961538    11992308
# 18        Slovakia  27.269231  184.423077  33.153846  2.576923     6026923
# 19        Slovenia  27.346154  184.923077  29.653846  3.000000     5365385
# 20           Spain  26.961538  181.769231  20.576923  3.653846    37134615
# 21     Switzerland  27.692308  183.923077  42.000000  4.807692    10846154
# 22          Turkey  25.807692  183.923077  24.307692  2.730769    12465385
# 23         Ukraine  26.346154  184.346154  32.653846  4.384615    14576923

# %% [markdown]
# #Historical results

# %% [markdown]
# Historical results refer to the games the nation has previously played. These can be interesting data points as they point to a team's quality and ability to win in recent times. Data from as early as 1872 clearly isn't particularly relevant to this summer's tournament so results will only be considered if they are after the most recent Eurpoean Football Championships (Summer 2021). Data from teams not competing in this summer's tournament will not be considered. A win percentage of the competing teams will be calculated showing their ability to win games across the last 3 years. The win percentage statistic will give an indicator of the nation's match winning ability over the course of the last 3 years.

# %%
#Data was downloaded from: https://www.kaggle.com/datasets/martj42/international-football-results-from-1872-to-2017?select=results.csv
results = pd.read_csv('results.csv', encoding = 'ISO-8859-1')
results
# Out:
#              date home_team away_team  home_score  away_score tournament  \
# 0      1872-11-30  Scotland   England         0.0         0.0   Friendly
# 1      1873-03-08   England  Scotland         4.0         2.0   Friendly
# 2      1874-03-07  Scotland   England         2.0         1.0   Friendly
# 3      1875-03-06   England  Scotland         2.0         2.0   Friendly
# 4      1876-03-04  Scotland   England         3.0         0.0   Friendly
# ...           ...       ...       ...         ...         ...        ...
# 47320  2024-07-06       NaN       NaN         NaN         NaN  UEFA Euro
# 47321  2024-07-06       NaN       NaN         NaN         NaN  UEFA Euro
# 47322  2024-07-09       NaN       NaN         NaN         NaN  UEFA Euro
# 47323  2024-07-10       NaN       NaN         NaN         NaN  UEFA Euro
# 47324  2024-07-14       NaN       NaN         NaN         NaN  UEFA Euro
#
#               city   country  neutral
# 0          Glasgow  Scotland    False
# 1           London   England    False
# 2          Glasgow  Scotland    False
# 3           London   England    False
# 4          Glasgow  Scotland    False
# ...            ...       ...      ...
# 47320  DÃ¼sseldorf   Germany     True
# 47321       Berlin   Germany     True
# 47322       Munich   Germany     True
# 47323     Dortmund   Germany     True
# 47324       Berlin   Germany     True
#
# [47325 rows x 9 columns]

# %%
# Convert 'Date' column to datetime format
results['date'] = pd.to_datetime(results['date'])
# Define the cutoff date
cutoff_date = pd.Timestamp('2021-07-12') #Day after last euros tournament final
cutoff_date2 = pd.Timestamp('2024-06-12') #Day of data collection
# Filter out rows where the date is past the cutoff date
results_filtered = results[(results['date'] > cutoff_date) & (results['date'] < cutoff_date2)]
results_filtered
# Out:
#             date              home_team               away_team  home_score  \
# 44159 2021-07-13               Botswana                  Zambia         1.0
# 44160 2021-07-13           South Africa                 Lesotho         4.0
# 44161 2021-07-13                Senegal                Zimbabwe         2.0
# 44162 2021-07-13                 Malawi                 Namibia         1.0
# 44163 2021-07-13                  Qatar                  Panama         3.0
# ...          ...                    ...                     ...         ...
# 47262 2024-06-11  Saint Kitts and Nevis                 Bahamas         1.0
# 47263 2024-06-11            Saint Lucia                   Aruba         2.0
# 47264 2024-06-11                 Guyana                  Belize         3.0
# 47265 2024-06-11     Dominican Republic  British Virgin Islands         4.0
# 47266 2024-06-11            Puerto Rico                Anguilla         8.0
#
#        away_score                    tournament            city  \
# 44159         2.0                    COSAFA Cup  Port Elizabeth
# 44160         0.0                    COSAFA Cup  Port Elizabeth
# 44161         1.0                    COSAFA Cup  Port Elizabeth
# 44162         1.0                    COSAFA Cup  Port Elizabeth
# 44163         3.0                      Gold Cup         Houston
# ...           ...                           ...             ...
# 47262         0.0  FIFA World Cup qualification      Basseterre
# 47263         2.0  FIFA World Cup qualification      Bridgetown
# 47264         1.0  FIFA World Cup qualification      Bridgetown
# 47265         0.0  FIFA World Cup qualification  San CristÃ³bal
# 47266         0.0  FIFA World Cup qualification        BayamÃ³n
#
#                      country  neutral
# 44159           South Africa     True
# 44160           South Africa    False
# 44161           South Africa     True
# 44162           South Africa     True
# 44163          United States     True
# ...                      ...      ...
# 47262  Saint Kitts and Nevis    False
# 47263               Barbados     True
# 47264               Barbados     True
# 47265     Dominican Republic    False
# 47266            Puerto Rico    False
#
# [3108 rows x 9 columns]

# %%
# Filter rows where either home_team or away_team is in df_sorted['Team']
filtered_results2 = results_filtered[(results_filtered['home_team'].isin(df_sorted['Team'])) | (results_filtered['away_team'].isin(df_sorted['Team']))]
filtered_results2
# Out:
#             date       home_team               away_team  home_score  \
# 44204 2021-09-01           Qatar                  Serbia         0.0
# 44205 2021-09-01     Switzerland                  Greece         2.0
# 44212 2021-09-01        Portugal     Republic of Ireland         2.0
# 44214 2021-09-01      Kazakhstan                 Ukraine         2.0
# 44215 2021-09-01          France  Bosnia and Herzegovina         1.0
# ...          ...             ...                     ...         ...
# 47207 2024-06-10  Czech Republic         North Macedonia         2.0
# 47208 2024-06-10     Netherlands                 Iceland         4.0
# 47209 2024-06-10          Poland                  Turkey         2.0
# 47226 2024-06-11         Moldova                 Ukraine         0.0
# 47228 2024-06-11        Portugal     Republic of Ireland         3.0
#
#        away_score                    tournament              city  \
# 44204         4.0                      Friendly          Debrecen
# 44205         1.0                      Friendly             Basel
# 44212         1.0  FIFA World Cup qualification       Faro-LoulÃ©
# 44214         2.0  FIFA World Cup qualification        Nur-Sultan
# 44215         1.0  FIFA World Cup qualification        Strasbourg
# ...           ...                           ...               ...
# 47207         1.0                      Friendly  Hradec KrÃ¡lovÃ©
# 47208         0.0                      Friendly         Rotterdam
# 47209         1.0                      Friendly            Warsaw
# 47226         4.0                      Friendly        ChiÈinÄu
# 47228         0.0                      Friendly            Aviero
#
#               country  neutral
# 44204         Hungary     True
# 44205     Switzerland    False
# 44212        Portugal    False
# 44214      Kazakhstan    False
# 44215          France    False
# ...               ...      ...
# 47207  Czech Republic    False
# 47208     Netherlands    False
# 47209          Poland    False
# 47226         Moldova    False
# 47228        Portugal    False
#
# [617 rows x 9 columns]

# %%
# Initialize a list to store results
teams_stats_list = []

# Extract unique teams from managers_sorted
selected_teams = managers_sorted['Team'].unique()

# Filter results to include only selected teams
filtered_results = filtered_results2[(filtered_results2['home_team'].isin(selected_teams)) | (filtered_results2['away_team'].isin(selected_teams))]

# Calculate stats for each selected team
for team in selected_teams:
    matches_played = len(filtered_results[(filtered_results['home_team'] == team) | (filtered_results['away_team'] == team)])
    wins = len(filtered_results[((filtered_results['home_team'] == team) & (filtered_results['home_score'] > filtered_results['away_score'])) |
                                ((filtered_results['away_team'] == team) & (filtered_results['away_score'] > filtered_results['home_score']))])
    draws = len(filtered_results[((filtered_results['home_team'] == team) | (filtered_results['away_team'] == team)) &
                                 (filtered_results['home_score'] == filtered_results['away_score'])])
    win_percentage = (wins / matches_played) * 100 if matches_played > 0 else 0

    # Append results to teams_stats DataFrame
    teams_stats_list.append({'Team': team, 'Win Percentage': win_percentage})

# Create DataFrame from teams_stats_list
teams_stats = pd.DataFrame(teams_stats_list)

# Sort the DataFrame by Team
teams_stats = teams_stats.sort_values(by='Team').reset_index(drop=True)

print(teams_stats)
# Out:
#               Team  Win Percentage
# 0          Albania       38.709677
# 1          Austria       54.838710
# 2          Belgium       57.575758
# 3          Croatia       59.459459
# 4   Czech Republic       48.387097
# 5          Denmark       65.625000
# 6          England       55.882353
# 7           France       63.888889
# 8          Georgia       51.724138
# 9          Germany       50.000000
# 10         Hungary       54.838710
# 11           Italy       46.875000
# 12     Netherlands       67.647059
# 13          Poland       52.941176
# 14        Portugal       75.000000
# 15         Romania       41.935484
# 16        Scotland       51.612903
# 17          Serbia       60.606061
# 18        Slovakia       45.161290
# 19        Slovenia       50.000000
# 20           Spain       64.705882
# 21     Switzerland       44.117647
# 22          Turkey       51.612903
# 23         Ukraine       44.827586

# %% [markdown]
# #Titles

# %% [markdown]
# Titles in this context means the number of Eurpoean Football Championships each of the competing countries have one before. An ability to win these tournaments in the past may be beneficial to a countries chances of winnning it again.

# %%
#Data was copied from: https://www.uefa.com/uefaeuro/history/winners/
titles = pd.read_csv('Titles.csv')
titles
# Out:
#         Country  Titles
# 0       Germany     3.0
# 1         Spain     3.0
# 2         Italy     2.0
# 3        France     2.0
# 4   Netherlands     1.0
# 5       Czechia     1.0
# 6      Slovakia     1.0
# 7        Russia     1.0
# 8        Greece     1.0
# 9       Denmark     1.0
# 10     Portugal     1.0
# 11          NaN     NaN

# %%
titles.drop(titles.tail(1).index,inplace=True)

# %%
titles = titles.rename(columns={'Country': 'Team'})
titles.head(3)
# Out:
#       Team  Titles
# 0  Germany     3.0
# 1    Spain     3.0
# 2    Italy     2.0

# %%
#Drop Russia, Greece from titles as they are not competing this year
titles = titles[~titles['Team'].isin(['Russia', 'Greece'])]
#Rename Czechia as Czech republic
titles.loc[titles['Team'] == 'Czechia', 'Team'] = 'Czech Republic'

# %%
titles
# Out:
#               Team  Titles
# 0          Germany     3.0
# 1            Spain     3.0
# 2            Italy     2.0
# 3           France     2.0
# 4      Netherlands     1.0
# 5   Czech Republic     1.0
# 6         Slovakia     1.0
# 9          Denmark     1.0
# 10        Portugal     1.0

# %% [markdown]
# #Qualifying stats

# %% [markdown]
# Qualifying statistics refer to the manner in which each nation qualified for the tournament. The host nation (Germany) automatically qualify so data reffering to the other 23 competing countries will be collected.

# %%
#https://footystats.org/international/uefa-euro-qualifiers
quali = pd.read_csv('Qualifying.csv')
quali
# Out:
#      Unnamed: 0        Team    MP     W    D     L    GF    GA    GD Last 5  \
# 0           1.0    Portugal  10.0  10.0  0.0   0.0  36.0   2.0  34.0      W
# 1           NaN         NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      W
# 2           NaN         NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      W
# 3           NaN         NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      W
# 4           NaN         NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      W
# ..          ...         ...   ...   ...  ...   ...   ...   ...   ...    ...
# 260        53.0  San Marino  10.0   0.0  0.0  10.0   3.0  31.0 -28.0      L
# 261         NaN         NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      L
# 262         NaN         NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      L
# 263         NaN         NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      L
# 264         NaN         NaN   NaN   NaN  NaN   NaN   NaN   NaN   NaN      L
#
#      Form   CS BTTS   xGF  1.5+ 2.5+  AVG
# 0     3.0  90%  10%  2.46   80%  60%  3.8
# 1     NaN  NaN  NaN   NaN   NaN  NaN  NaN
# 2     NaN  NaN  NaN   NaN   NaN  NaN  NaN
# 3     NaN  NaN  NaN   NaN   NaN  NaN  NaN
# 4     NaN  NaN  NaN   NaN   NaN  NaN  NaN
# ..    ...  ...  ...   ...   ...  ...  ...
# 260   0.0   0%  30%  0.38  100%  80%  3.4
# 261   NaN  NaN  NaN   NaN   NaN  NaN  NaN
# 262   NaN  NaN  NaN   NaN   NaN  NaN  NaN
# 263   NaN  NaN  NaN   NaN   NaN  NaN  NaN
# 264   NaN  NaN  NaN   NaN   NaN  NaN  NaN
#
# [265 rows x 17 columns]

# %% [markdown]
# The last 5 column in this instance is causing an unusual pattern in the dataset. As this column is represented in the Form column, the datset can be compacted to one row per country

# %%
quali = quali.dropna(subset='Team')
quali
# Out:
#      Unnamed: 0                 Team    MP     W    D     L    GF    GA    GD  \
# 0           1.0             Portugal  10.0  10.0  0.0   0.0  36.0   2.0  34.0
# 5           2.0              Denmark  10.0   7.0  1.0   2.0  19.0  10.0   9.0
# 10          3.0               France   8.0   7.0  1.0   0.0  29.0   3.0  26.0
# 15          4.0             Slovakia  10.0   7.0  1.0   2.0  17.0   8.0   9.0
# 20          5.0             Slovenia  10.0   7.0  1.0   2.0  20.0   9.0  11.0
# 25          6.0              Romania  10.0   6.0  4.0   0.0  16.0   5.0  11.0
# 30          7.0                Spain   8.0   7.0  0.0   1.0  25.0   5.0  20.0
# 35          8.0              England   8.0   6.0  2.0   0.0  22.0   4.0  18.0
# 40          9.0              Belgium   8.0   6.0  2.0   0.0  22.0   4.0  18.0
# 45         10.0              Ukraine  10.0   6.0  2.0   2.0  15.0  10.0   5.0
# 50         11.0              Austria   8.0   6.0  1.0   1.0  17.0   7.0  10.0
# 55         12.0          Netherlands   8.0   6.0  0.0   2.0  17.0   7.0  10.0
# 60         13.0              Hungary   8.0   5.0  3.0   0.0  16.0   7.0   9.0
# 65         14.0              Finland  11.0   6.0  0.0   5.0  19.0  14.0   5.0
# 70         15.0           Kazakhstan  11.0   6.0  0.0   5.0  16.0  17.0  -1.0
# 75         16.0               Greece  10.0   5.0  2.0   3.0  19.0   8.0  11.0
# 80         17.0             Scotland   8.0   5.0  2.0   1.0  17.0   8.0   9.0
# 85         18.0               Turkey   8.0   5.0  2.0   1.0  14.0   7.0   7.0
# 90         19.0          Switzerland  10.0   4.0  5.0   1.0  22.0  11.0  11.0
# 95         20.0           Luxembourg  11.0   5.0  2.0   4.0  13.0  21.0  -8.0
# 100        21.0                Wales  10.0   4.0  4.0   2.0  14.0  11.0   3.0
# 105        22.0              Croatia   8.0   5.0  1.0   2.0  13.0   4.0   9.0
# 110        23.0       Czech Republic   8.0   4.0  3.0   1.0  12.0   6.0   6.0
# 115        24.0               Poland  10.0   4.0  3.0   3.0  15.0  11.0   4.0
# 120        25.0              Albania   8.0   4.0  3.0   1.0  12.0   4.0   8.0
# 125        26.0               Israel  11.0   4.0  3.0   4.0  12.0  15.0  -3.0
# 130        27.0               Serbia   8.0   4.0  2.0   2.0  15.0   9.0   6.0
# 135        28.0                Italy   8.0   4.0  2.0   2.0  16.0   9.0   7.0
# 140        29.0              Iceland  12.0   4.0  1.0   7.0  22.0  19.0   3.0
# 145        30.0              Belarus  10.0   3.0  3.0   4.0   9.0  14.0  -5.0
# 150        31.0              Georgia  10.0   3.0  3.0   4.0  14.0  18.0  -4.0
# 155        32.0               Kosovo  10.0   2.0  5.0   3.0  10.0  10.0   0.0
# 160        33.0               Norway   8.0   3.0  2.0   3.0  14.0  12.0   2.0
# 165        34.0           Montenegro   8.0   3.0  2.0   3.0   9.0  11.0  -2.0
# 170        35.0               Sweden   8.0   3.0  1.0   4.0  14.0  12.0   2.0
# 175        36.0              Moldova   8.0   2.0  4.0   2.0   7.0  10.0  -3.0
# 180        37.0   Bosnia-Herzegovina  11.0   3.0  0.0   8.0  10.0  22.0 -12.0
# 185        38.0     Northern Ireland  10.0   3.0  0.0   7.0   9.0  13.0  -4.0
# 190        39.0              Armenia   8.0   2.0  2.0   4.0   9.0  11.0  -2.0
# 195        40.0        FYR Macedonia   8.0   2.0  2.0   4.0  10.0  20.0 -10.0
# 200        41.0           Azerbaijan   8.0   2.0  1.0   5.0   7.0  17.0 -10.0
# 205        42.0  Republic of Ireland   8.0   2.0  0.0   6.0   9.0  10.0  -1.0
# 210        43.0            Lithuania   8.0   1.0  3.0   4.0   8.0  14.0  -6.0
# 215        44.0             Bulgaria   8.0   0.0  4.0   4.0   7.0  14.0  -7.0
# 220        45.0               Latvia   8.0   1.0  0.0   7.0   5.0  19.0 -14.0
# 225        46.0              Andorra  10.0   0.0  2.0   8.0   3.0  20.0 -17.0
# 230        47.0        Faroe Islands   8.0   0.0  2.0   6.0   2.0  13.0 -11.0
# 235        48.0              Estonia   9.0   0.0  1.0   8.0   3.0  27.0 -24.0
# 240        49.0                Malta   8.0   0.0  0.0   8.0   2.0  20.0 -18.0
# 245        50.0            Gibraltar   8.0   0.0  0.0   8.0   0.0  41.0 -41.0
# 250        51.0               Cyprus   8.0   0.0  0.0   8.0   3.0  28.0 -25.0
# 255        52.0        Liechtenstein  10.0   0.0  0.0  10.0   1.0  28.0 -27.0
# 260        53.0           San Marino  10.0   0.0  0.0  10.0   3.0  31.0 -28.0
#
#     Last 5  Form   CS BTTS   xGF  1.5+  2.5+   AVG
# 0        W  3.00  90%  10%  2.46   80%   60%  3.80
# 5        W  2.20  30%  60%  1.90   80%   60%  2.90
# 10       W  2.75  75%  25%  2.57   75%   63%  4.00
# 15       W  2.20  50%  40%  1.37   60%   50%  2.50
# 20       W  2.20  40%  50%  1.41   90%   60%  2.90
# 25       W  2.20  60%  40%  1.55   70%   40%  2.10
# 30       W  2.63  50%  38%  2.29   88%   63%  3.75
# 35       W  2.50  50%  50%  1.56  100%   50%  3.25
# 40       W  2.50  63%  38%  1.73   88%   63%  3.25
# 45       W  2.00  30%  60%  1.21   80%   50%  2.50
# 50       W  2.38  38%  63%  1.91   88%   50%  3.00
# 55       W  2.25  63%  25%  2.01   75%   75%  3.00
# 60       W  2.25  38%  63%  1.67   88%   75%  2.88
# 65       L  1.64  45%  36%  1.26   73%   64%  3.00
# 70       L  1.64  27%  55%  1.15   73%   73%  3.00
# 75       W  1.70  50%  20%  1.56   70%   60%  2.70
# 80       W  2.13  50%  38%  1.16  100%   63%  3.13
# 85       W  2.13  38%  50%  1.79   88%   38%  2.63
# 90       W  1.70  30%  60%  2.16   90%   70%  3.30
# 95       D  1.55  36%  27%  0.98   73%   36%  3.09
# 100      W  1.60  30%  60%  1.42   80%   30%  2.50
# 105      W  2.00  63%  25%  2.23   63%   25%  2.13
# 110      D  1.88  50%  38%  1.83   75%   50%  2.25
# 115      W  1.50  40%  50%  1.73   80%   30%  2.60
# 120      D  1.88  50%  38%  1.13   75%   25%  2.00
# 125      L  1.36  18%  64%  1.59   82%   45%  2.45
# 130      L  1.75  25%  75%  1.68  100%   63%  3.00
# 135      W  1.75  38%  63%  1.66   88%   63%  3.13
# 140      W  1.08  25%  50%  1.40   83%   67%  3.42
# 145      L  1.20  40%  40%  1.00   50%   50%  2.30
# 150      W  1.20  30%  60%  1.00   90%   60%  3.20
# 155      L  1.10  30%  50%  1.43   70%   30%  2.00
# 160      W  1.38  13%  63%  1.55   88%   75%  3.25
# 165      D  1.38  38%  50%  1.43   75%   50%  2.50
# 170      W  1.25  38%  25%  1.58  100%   63%  3.25
# 175      W  1.25  25%  50%  0.90   75%   25%  2.13
# 180      W  0.82  18%  36%  1.21   91%   64%  2.91
# 185      L  0.90  30%  10%  1.30   50%   30%  2.20
# 190      D  1.00   0%  63%  1.22   75%   38%  2.50
# 195      D  1.00  13%  63%  0.87  100%   50%  3.75
# 200      L  0.88  25%  25%  0.75   75%   50%  3.00
# 205      L  0.75  25%  25%  1.59   75%   50%  2.38
# 210      D  0.75  13%  50%  0.85  100%   38%  2.75
# 215      D  0.50   0%  63%  1.21   88%   50%  2.63
# 220      L  0.38  13%  25%  0.91   88%   50%  3.00
# 225      L  0.20  10%  30%  0.46   80%   50%  2.30
# 230      L  0.25  13%  25%  0.50   63%   25%  1.88
# 235      L  0.11   0%  33%  0.68  100%   56%  3.33
# 240      L  0.00   0%  25%  0.50   88%   50%  2.75
# 245      L  0.00   0%   0%  0.15  100%  100%  5.13
# 250      L  0.00   0%  38%  0.70  100%  100%  3.88
# 255      L  0.00   0%  10%  0.46   80%   50%  2.90
# 260      L  0.00   0%  30%  0.38  100%   80%  3.40

# %% [markdown]
# Drop unneccessary columns, Last 5 is represented in the form column as stated previously.

# %%
columns_to_drop = ['Unnamed: 0', 'Last 5']
quali = quali.drop(columns=columns_to_drop)
quali.head(3)
# Out:
#         Team    MP     W    D    L    GF    GA    GD  Form   CS BTTS   xGF  \
# 0   Portugal  10.0  10.0  0.0  0.0  36.0   2.0  34.0  3.00  90%  10%  2.46
# 5    Denmark  10.0   7.0  1.0  2.0  19.0  10.0   9.0  2.20  30%  60%  1.90
# 10    France   8.0   7.0  1.0  0.0  29.0   3.0  26.0  2.75  75%  25%  2.57
#
#    1.5+ 2.5+  AVG
# 0   80%  60%  3.8
# 5   80%  60%  2.9
# 10  75%  63%  4.0

# %%
quali = quali.reset_index(drop=True)
quali.head(3)
# Out:
#        Team    MP     W    D    L    GF    GA    GD  Form   CS BTTS   xGF  \
# 0  Portugal  10.0  10.0  0.0  0.0  36.0   2.0  34.0  3.00  90%  10%  2.46
# 1   Denmark  10.0   7.0  1.0  2.0  19.0  10.0   9.0  2.20  30%  60%  1.90
# 2    France   8.0   7.0  1.0  0.0  29.0   3.0  26.0  2.75  75%  25%  2.57
#
#   1.5+ 2.5+  AVG
# 0  80%  60%  3.8
# 1  80%  60%  2.9
# 2  75%  63%  4.0

# %% [markdown]
# The form feature encapsulates the team's playing data. In qualifying, a team gets 3 points for a win, 1 for a draw and 0 for a loss. For instance Portugal have played 10 games and won 10 games meaning they end on 30 points. This data can be represented in a single cell by total points (30) / games played (10) = Form (3). This feature shows the number of points per game each team achieved across their qualifying period.
#
# This feature encapsulates all match statistics i,e MP, W, L, D ao they can be dropped.
# Features BTTS, 1.5+, 2.5+, AVG, refer to more specific in-game statistics that aren't important in this analysis, so they are also dropped.

# %%
#Form encapsulates MP, W, D, L
##Last 3 columns and BTTS refer to team and opponent so not suitable
columns_to_drop = ['MP', 'W', 'D', 'L', 'BTTS', '1.5+', '2.5+', 'AVG']
quali = quali.drop(columns=columns_to_drop)
quali.head(3)
# Out:
#        Team    GF    GA    GD  Form   CS   xGF
# 0  Portugal  36.0   2.0  34.0  3.00  90%  2.46
# 1   Denmark  19.0  10.0   9.0  2.20  30%  1.90
# 2    France  29.0   3.0  26.0  2.75  75%  2.57

# %%
# Sort table alphabetically by Team
quali_sorted = quali.sort_values(by='Team')
# Reset index after dropping rows and rearranging order
quali_sorted.reset_index(drop=True, inplace=True)
quali_sorted.head(3)
# Out:
#       Team    GF    GA    GD  Form   CS   xGF
# 0  Albania  12.0   4.0   8.0  1.88  50%  1.13
# 1  Andorra   3.0  20.0 -17.0  0.20  10%  0.46
# 2  Armenia   9.0  11.0  -2.0  1.00   0%  1.22

# %%
# Define new column names
new_column_names = {
    'Team': 'Team',
    'GF': 'Q_GF',
    'GA': 'Q_GA',
    'GD': 'Q_GD',
    'Form': 'Q_PPG_Last_5',
    'CS': 'Q_Clean_Sheets',
    'xGF': 'Q_xGF',
}

# Rename columns
quali_sorted = quali_sorted.rename(columns=new_column_names)

quali_sorted.head(3)
# Out:
#       Team  Q_GF  Q_GA  Q_GD  Q_PPG_Last_5 Q_Clean_Sheets  Q_xGF
# 0  Albania  12.0   4.0   8.0          1.88            50%   1.13
# 1  Andorra   3.0  20.0 -17.0          0.20            10%   0.46
# 2  Armenia   9.0  11.0  -2.0          1.00             0%   1.22

# %%
quali_sorted
# Out:
#                    Team  Q_GF  Q_GA  Q_GD  Q_PPG_Last_5 Q_Clean_Sheets  Q_xGF
# 0               Albania  12.0   4.0   8.0          1.88            50%   1.13
# 1               Andorra   3.0  20.0 -17.0          0.20            10%   0.46
# 2               Armenia   9.0  11.0  -2.0          1.00             0%   1.22
# 3               Austria  17.0   7.0  10.0          2.38            38%   1.91
# 4            Azerbaijan   7.0  17.0 -10.0          0.88            25%   0.75
# 5               Belarus   9.0  14.0  -5.0          1.20            40%   1.00
# 6               Belgium  22.0   4.0  18.0          2.50            63%   1.73
# 7    Bosnia-Herzegovina  10.0  22.0 -12.0          0.82            18%   1.21
# 8              Bulgaria   7.0  14.0  -7.0          0.50             0%   1.21
# 9               Croatia  13.0   4.0   9.0          2.00            63%   2.23
# 10               Cyprus   3.0  28.0 -25.0          0.00             0%   0.70
# 11       Czech Republic  12.0   6.0   6.0          1.88            50%   1.83
# 12              Denmark  19.0  10.0   9.0          2.20            30%   1.90
# 13              England  22.0   4.0  18.0          2.50            50%   1.56
# 14              Estonia   3.0  27.0 -24.0          0.11             0%   0.68
# 15        FYR Macedonia  10.0  20.0 -10.0          1.00            13%   0.87
# 16        Faroe Islands   2.0  13.0 -11.0          0.25            13%   0.50
# 17              Finland  19.0  14.0   5.0          1.64            45%   1.26
# 18               France  29.0   3.0  26.0          2.75            75%   2.57
# 19              Georgia  14.0  18.0  -4.0          1.20            30%   1.00
# 20            Gibraltar   0.0  41.0 -41.0          0.00             0%   0.15
# 21               Greece  19.0   8.0  11.0          1.70            50%   1.56
# 22              Hungary  16.0   7.0   9.0          2.25            38%   1.67
# 23              Iceland  22.0  19.0   3.0          1.08            25%   1.40
# 24               Israel  12.0  15.0  -3.0          1.36            18%   1.59
# 25                Italy  16.0   9.0   7.0          1.75            38%   1.66
# 26           Kazakhstan  16.0  17.0  -1.0          1.64            27%   1.15
# 27               Kosovo  10.0  10.0   0.0          1.10            30%   1.43
# 28               Latvia   5.0  19.0 -14.0          0.38            13%   0.91
# 29        Liechtenstein   1.0  28.0 -27.0          0.00             0%   0.46
# 30            Lithuania   8.0  14.0  -6.0          0.75            13%   0.85
# 31           Luxembourg  13.0  21.0  -8.0          1.55            36%   0.98
# 32                Malta   2.0  20.0 -18.0          0.00             0%   0.50
# 33              Moldova   7.0  10.0  -3.0          1.25            25%   0.90
# 34           Montenegro   9.0  11.0  -2.0          1.38            38%   1.43
# 35          Netherlands  17.0   7.0  10.0          2.25            63%   2.01
# 36     Northern Ireland   9.0  13.0  -4.0          0.90            30%   1.30
# 37               Norway  14.0  12.0   2.0          1.38            13%   1.55
# 38               Poland  15.0  11.0   4.0          1.50            40%   1.73
# 39             Portugal  36.0   2.0  34.0          3.00            90%   2.46
# 40  Republic of Ireland   9.0  10.0  -1.0          0.75            25%   1.59
# 41              Romania  16.0   5.0  11.0          2.20            60%   1.55
# 42           San Marino   3.0  31.0 -28.0          0.00             0%   0.38
# 43             Scotland  17.0   8.0   9.0          2.13            50%   1.16
# 44               Serbia  15.0   9.0   6.0          1.75            25%   1.68
# 45             Slovakia  17.0   8.0   9.0          2.20            50%   1.37
# 46             Slovenia  20.0   9.0  11.0          2.20            40%   1.41
# 47                Spain  25.0   5.0  20.0          2.63            50%   2.29
# 48               Sweden  14.0  12.0   2.0          1.25            38%   1.58
# 49          Switzerland  22.0  11.0  11.0          1.70            30%   2.16
# 50               Turkey  14.0   7.0   7.0          2.13            38%   1.79
# 51              Ukraine  15.0  10.0   5.0          2.00            30%   1.21
# 52                Wales  14.0  11.0   3.0          1.60            30%   1.42

# %% [markdown]
# The dataset above contains data about all teams who attempted to qualify for the tournment. This analysis will only focus on those teams competing at the tournament so they are isolated.

# %%
#Isolate teams in competition
competing_countries = players_grouped['Team'].unique()
# Filter the quali_sorted dataset to include only rows with countries in competing_countries
quali_sorted_filtered = quali_sorted[quali_sorted['Team'].isin(competing_countries)]
# Print the filtered DataFrame
print(quali_sorted_filtered)
# Out:
#               Team  Q_GF  Q_GA  Q_GD  Q_PPG_Last_5 Q_Clean_Sheets  Q_xGF
# 0          Albania  12.0   4.0   8.0          1.88            50%   1.13
# 3          Austria  17.0   7.0  10.0          2.38            38%   1.91
# 6          Belgium  22.0   4.0  18.0          2.50            63%   1.73
# 9          Croatia  13.0   4.0   9.0          2.00            63%   2.23
# 11  Czech Republic  12.0   6.0   6.0          1.88            50%   1.83
# 12         Denmark  19.0  10.0   9.0          2.20            30%   1.90
# 13         England  22.0   4.0  18.0          2.50            50%   1.56
# 18          France  29.0   3.0  26.0          2.75            75%   2.57
# 19         Georgia  14.0  18.0  -4.0          1.20            30%   1.00
# 22         Hungary  16.0   7.0   9.0          2.25            38%   1.67
# 25           Italy  16.0   9.0   7.0          1.75            38%   1.66
# 35     Netherlands  17.0   7.0  10.0          2.25            63%   2.01
# 38          Poland  15.0  11.0   4.0          1.50            40%   1.73
# 39        Portugal  36.0   2.0  34.0          3.00            90%   2.46
# 41         Romania  16.0   5.0  11.0          2.20            60%   1.55
# 43        Scotland  17.0   8.0   9.0          2.13            50%   1.16
# 44          Serbia  15.0   9.0   6.0          1.75            25%   1.68
# 45        Slovakia  17.0   8.0   9.0          2.20            50%   1.37
# 46        Slovenia  20.0   9.0  11.0          2.20            40%   1.41
# 47           Spain  25.0   5.0  20.0          2.63            50%   2.29
# 49     Switzerland  22.0  11.0  11.0          1.70            30%   2.16
# 50          Turkey  14.0   7.0   7.0          2.13            38%   1.79
# 51         Ukraine  15.0  10.0   5.0          2.00            30%   1.21

# %%
quali_sorted_filtered
# Out:
#               Team  Q_GF  Q_GA  Q_GD  Q_PPG_Last_5 Q_Clean_Sheets  Q_xGF
# 0          Albania  12.0   4.0   8.0          1.88            50%   1.13
# 3          Austria  17.0   7.0  10.0          2.38            38%   1.91
# 6          Belgium  22.0   4.0  18.0          2.50            63%   1.73
# 9          Croatia  13.0   4.0   9.0          2.00            63%   2.23
# 11  Czech Republic  12.0   6.0   6.0          1.88            50%   1.83
# 12         Denmark  19.0  10.0   9.0          2.20            30%   1.90
# 13         England  22.0   4.0  18.0          2.50            50%   1.56
# 18          France  29.0   3.0  26.0          2.75            75%   2.57
# 19         Georgia  14.0  18.0  -4.0          1.20            30%   1.00
# 22         Hungary  16.0   7.0   9.0          2.25            38%   1.67
# 25           Italy  16.0   9.0   7.0          1.75            38%   1.66
# 35     Netherlands  17.0   7.0  10.0          2.25            63%   2.01
# 38          Poland  15.0  11.0   4.0          1.50            40%   1.73
# 39        Portugal  36.0   2.0  34.0          3.00            90%   2.46
# 41         Romania  16.0   5.0  11.0          2.20            60%   1.55
# 43        Scotland  17.0   8.0   9.0          2.13            50%   1.16
# 44          Serbia  15.0   9.0   6.0          1.75            25%   1.68
# 45        Slovakia  17.0   8.0   9.0          2.20            50%   1.37
# 46        Slovenia  20.0   9.0  11.0          2.20            40%   1.41
# 47           Spain  25.0   5.0  20.0          2.63            50%   2.29
# 49     Switzerland  22.0  11.0  11.0          1.70            30%   2.16
# 50          Turkey  14.0   7.0   7.0          2.13            38%   1.79
# 51         Ukraine  15.0  10.0   5.0          2.00            30%   1.21

# %% [markdown]
# #Odds

# %% [markdown]
# Odds is the key, target feature in this analysis. It refers to the odds given to each country of winnning the tournament by British gambling company Bet365. Those with shorter odds are considered more likely to win the tournament.

# %%
#https://www.oddschecker.com/football/euro-2024/winner
#First column: BET365 used
odds = pd.read_csv('Odds.csv')
odds
# Out:
#               Team  Bet365
# 0          England   3.5/1
# 1           France   4.0/1
# 2          Germany   5.5/1
# 3         Portugal   6.5/1
# 4            Spain   8.0/1
# 5            Italy  14.0/1
# 6      Netherlands  16.0/1
# 7          Belgium  16.0/1
# 8          Croatia    40/1
# 9          Denmark    40/1
# 10         Austria    66/1
# 11     Switzerland    66/1
# 12         Ukraine   100/1
# 13          Turkey    50/1
# 14          Serbia    80/1
# 15         Hungary    80/1
# 16  Czech Republic   150/1
# 17         Romania   200/1
# 18        Scotland   100/1
# 19          Poland   150/1
# 20        Slovakia   500/1
# 21        Slovenia   250/1
# 22         Georgia   500/1
# 23         Albania   500/1

# %%
# Sort table alphabetically by Team
odds_sorted = odds.sort_values(by='Team')
# Reset index after dropping rows and rearranging order
odds_sorted.reset_index(drop=True, inplace=True)
odds_sorted
# Out:
#               Team  Bet365
# 0          Albania   500/1
# 1          Austria    66/1
# 2          Belgium  16.0/1
# 3          Croatia    40/1
# 4   Czech Republic   150/1
# 5          Denmark    40/1
# 6          England   3.5/1
# 7           France   4.0/1
# 8          Georgia   500/1
# 9          Germany   5.5/1
# 10         Hungary    80/1
# 11           Italy  14.0/1
# 12     Netherlands  16.0/1
# 13          Poland   150/1
# 14        Portugal   6.5/1
# 15         Romania   200/1
# 16        Scotland   100/1
# 17          Serbia    80/1
# 18        Slovakia   500/1
# 19        Slovenia   250/1
# 20           Spain   8.0/1
# 21     Switzerland    66/1
# 22          Turkey    50/1
# 23         Ukraine   100/1

# %% [markdown]
# #Merge datasets

# %% [markdown]
# Once this data has been collected and cleaned partially, it is merged to create one large dataset used for subsequent analysis. Each of the above datasets have been compacted to contain one row per nation meaning they can be merged easily.

# %%
merged_df = df_sorted.merge(odds_sorted, on='Team')
merged_df
# Out:
#               Team FIFA Rank  Bet365
# 0          Albania        66   500/1
# 1          Austria        25    66/1
# 2          Belgium         3  16.0/1
# 3          Croatia        10    40/1
# 4   Czech Republic        36   150/1
# 5          Denmark        21    40/1
# 6          England         4   3.5/1
# 7           France         2   4.0/1
# 8          Georgia        75   500/1
# 9          Germany        16   5.5/1
# 10         Hungary        26    80/1
# 11           Italy         9  14.0/1
# 12     Netherlands         7  16.0/1
# 13          Poland        28   150/1
# 14        Portugal         6   6.5/1
# 15         Romania        46   200/1
# 16        Scotland        39   100/1
# 17          Serbia        33    80/1
# 18        Slovakia        48   500/1
# 19        Slovenia        57   250/1
# 20           Spain         8   8.0/1
# 21     Switzerland        19    66/1
# 22          Turkey        40    50/1
# 23         Ukraine        22   100/1

# %%
merged_df2 = merged_df.merge(managers_sorted, on='Team')
merged_df2
# Out:
#               Team FIFA Rank  Bet365            Manager  Manager_Age  \
# 0          Albania        66   500/1           Sylvinho           50
# 1          Austria        25    66/1      Ralf Rangnick           65
# 2          Belgium         3  16.0/1   Domenico Tedesco           38
# 3          Croatia        10    40/1       Zlatko Dalic           57
# 4   Czech Republic        36   150/1         Ivan Hasek           60
# 5          Denmark        21    40/1    Kasper Hjulmand           52
# 6          England         4   3.5/1   Gareth Southgate           53
# 7           France         2   4.0/1   Didier Deschamps           55
# 8          Georgia        75   500/1       Willy Sagnol           47
# 9          Germany        16   5.5/1  Julian Nagelsmann           36
# 10         Hungary        26    80/1        Marco Rossi           59
# 11           Italy         9  14.0/1  Luciano Spalletti           65
# 12     Netherlands         7  16.0/1      Ronald Koeman           61
# 13          Poland        28   150/1    Michal Probierz           51
# 14        Portugal         6   6.5/1   Roberto Martínez           50
# 15         Romania        46   200/1  Edward Iord?nescu           45
# 16        Scotland        39   100/1       Steve Clarke           60
# 17          Serbia        33    80/1   Dragan Stojkovic           59
# 18        Slovakia        48   500/1  Francesco Calzona           55
# 19        Slovenia        57   250/1         Matjaz Kek           62
# 20           Spain         8   8.0/1  Luis de la Fuente           62
# 21     Switzerland        19    66/1        Murat Yakin           49
# 22          Turkey        40    50/1  Vincenzo Montella           49
# 23         Ukraine        22   100/1      Sergiy Rebrov           50
#
#                   Installation Contract until
# 0    01 year 05 months 10 days           2024
# 1             02 years 11 days           2025
# 2    01 year 04 months 04 days           2026
# 3   06 years 08 months 05 days           2026
# 4            05 months 08 days           2025
# 5   03 years 10 months 11 days           2026
# 6   07 years 08 months 15 days           2024
# 7   11 years 11 months 04 days           2026
# 8   03 years 03 months 28 days           2024
# 9            08 months 21 days           2026
# 10  05 years 11 months 24 days           2025
# 11           09 months 11 days           2026
# 12   01 year 05 months 11 days           2026
# 13           08 months 23 days              ?
# 14   01 year 05 months 03 days           2026
# 15  02 years 04 months 17 days           2024
# 16            05 years 23 days           2026
# 17  03 years 03 months 09 days              ?
# 18   01 year 11 months 03 days           2025
# 19  05 years 06 months 16 days           2025
# 20   01 year 05 months 11 days           2026
# 21  02 years 10 months 03 days           2024
# 22           08 months 22 days           2026
# 23             01 year 05 days           2026

# %% [markdown]
# Those countries not represented in the titles dataset have not won the Championships. Their record for this row is therefore 0.

# %%
merged_df3 = merged_df2.merge(titles, on='Team', how='outer')
# Fill missing values in the 'Titles' column with 0
merged_df3['Titles'] = merged_df3['Titles'].fillna(0)
merged_df3
# Out:
#               Team FIFA Rank  Bet365            Manager  Manager_Age  \
# 0          Albania        66   500/1           Sylvinho           50
# 1          Austria        25    66/1      Ralf Rangnick           65
# 2          Belgium         3  16.0/1   Domenico Tedesco           38
# 3          Croatia        10    40/1       Zlatko Dalic           57
# 4   Czech Republic        36   150/1         Ivan Hasek           60
# 5          Denmark        21    40/1    Kasper Hjulmand           52
# 6          England         4   3.5/1   Gareth Southgate           53
# 7           France         2   4.0/1   Didier Deschamps           55
# 8          Georgia        75   500/1       Willy Sagnol           47
# 9          Germany        16   5.5/1  Julian Nagelsmann           36
# 10         Hungary        26    80/1        Marco Rossi           59
# 11           Italy         9  14.0/1  Luciano Spalletti           65
# 12     Netherlands         7  16.0/1      Ronald Koeman           61
# 13          Poland        28   150/1    Michal Probierz           51
# 14        Portugal         6   6.5/1   Roberto Martínez           50
# 15         Romania        46   200/1  Edward Iord?nescu           45
# 16        Scotland        39   100/1       Steve Clarke           60
# 17          Serbia        33    80/1   Dragan Stojkovic           59
# 18        Slovakia        48   500/1  Francesco Calzona           55
# 19        Slovenia        57   250/1         Matjaz Kek           62
# 20           Spain         8   8.0/1  Luis de la Fuente           62
# 21     Switzerland        19    66/1        Murat Yakin           49
# 22          Turkey        40    50/1  Vincenzo Montella           49
# 23         Ukraine        22   100/1      Sergiy Rebrov           50
#
#                   Installation Contract until  Titles
# 0    01 year 05 months 10 days           2024     0.0
# 1             02 years 11 days           2025     0.0
# 2    01 year 04 months 04 days           2026     0.0
# 3   06 years 08 months 05 days           2026     0.0
# 4            05 months 08 days           2025     1.0
# 5   03 years 10 months 11 days           2026     1.0
# 6   07 years 08 months 15 days           2024     0.0
# 7   11 years 11 months 04 days           2026     2.0
# 8   03 years 03 months 28 days           2024     0.0
# 9            08 months 21 days           2026     3.0
# 10  05 years 11 months 24 days           2025     0.0
# 11           09 months 11 days           2026     2.0
# 12   01 year 05 months 11 days           2026     1.0
# 13           08 months 23 days              ?     0.0
# 14   01 year 05 months 03 days           2026     1.0
# 15  02 years 04 months 17 days           2024     0.0
# 16            05 years 23 days           2026     0.0
# 17  03 years 03 months 09 days              ?     0.0
# 18   01 year 11 months 03 days           2025     1.0
# 19  05 years 06 months 16 days           2025     0.0
# 20   01 year 05 months 11 days           2026     3.0
# 21  02 years 10 months 03 days           2024     0.0
# 22           08 months 22 days           2026     0.0
# 23             01 year 05 days           2026     0.0

# %% [markdown]
# **Manager Contract until solution:** Upon further manual investigation Poland and Serbia's Manager contracts are both expiring in 2026, meaning this information can be passed into the dataset.

# %%
# Update contract end year for Poland and Serbia to 2026
merged_df3.loc[merged_df3['Team'] == 'Poland', 'Contract until'] = 2026
merged_df3.loc[merged_df3['Team'] == 'Serbia', 'Contract until'] = 2026
merged_df3
# Out:
#               Team FIFA Rank  Bet365            Manager  Manager_Age  \
# 0          Albania        66   500/1           Sylvinho           50
# 1          Austria        25    66/1      Ralf Rangnick           65
# 2          Belgium         3  16.0/1   Domenico Tedesco           38
# 3          Croatia        10    40/1       Zlatko Dalic           57
# 4   Czech Republic        36   150/1         Ivan Hasek           60
# 5          Denmark        21    40/1    Kasper Hjulmand           52
# 6          England         4   3.5/1   Gareth Southgate           53
# 7           France         2   4.0/1   Didier Deschamps           55
# 8          Georgia        75   500/1       Willy Sagnol           47
# 9          Germany        16   5.5/1  Julian Nagelsmann           36
# 10         Hungary        26    80/1        Marco Rossi           59
# 11           Italy         9  14.0/1  Luciano Spalletti           65
# 12     Netherlands         7  16.0/1      Ronald Koeman           61
# 13          Poland        28   150/1    Michal Probierz           51
# 14        Portugal         6   6.5/1   Roberto Martínez           50
# 15         Romania        46   200/1  Edward Iord?nescu           45
# 16        Scotland        39   100/1       Steve Clarke           60
# 17          Serbia        33    80/1   Dragan Stojkovic           59
# 18        Slovakia        48   500/1  Francesco Calzona           55
# 19        Slovenia        57   250/1         Matjaz Kek           62
# 20           Spain         8   8.0/1  Luis de la Fuente           62
# 21     Switzerland        19    66/1        Murat Yakin           49
# 22          Turkey        40    50/1  Vincenzo Montella           49
# 23         Ukraine        22   100/1      Sergiy Rebrov           50
#
#                   Installation Contract until  Titles
# 0    01 year 05 months 10 days           2024     0.0
# 1             02 years 11 days           2025     0.0
# 2    01 year 04 months 04 days           2026     0.0
# 3   06 years 08 months 05 days           2026     0.0
# 4            05 months 08 days           2025     1.0
# 5   03 years 10 months 11 days           2026     1.0
# 6   07 years 08 months 15 days           2024     0.0
# 7   11 years 11 months 04 days           2026     2.0
# 8   03 years 03 months 28 days           2024     0.0
# 9            08 months 21 days           2026     3.0
# 10  05 years 11 months 24 days           2025     0.0
# 11           09 months 11 days           2026     2.0
# 12   01 year 05 months 11 days           2026     1.0
# 13           08 months 23 days           2026     0.0
# 14   01 year 05 months 03 days           2026     1.0
# 15  02 years 04 months 17 days           2024     0.0
# 16            05 years 23 days           2026     0.0
# 17  03 years 03 months 09 days           2026     0.0
# 18   01 year 11 months 03 days           2025     1.0
# 19  05 years 06 months 16 days           2025     0.0
# 20   01 year 05 months 11 days           2026     3.0
# 21  02 years 10 months 03 days           2024     0.0
# 22           08 months 22 days           2026     0.0
# 23             01 year 05 days           2026     0.0

# %% [markdown]
# Currently, the 'Installation' column is not in a format that will be recognised by regression models i.e. 02 years 10 months 03 days. This needs to be converted into a numeric format. This is done by converting each of these records into total months. This metric won't take into account the days but still gives a reasonably representative metric pertaining to manager's time in charge.

# %%
# Convert 'Installation' column to total months
merged_df3['Months_installed'] = 0

# Split the 'Installation' column into components and calculate total months
for index, row in merged_df3.iterrows():
    components = row['Installation'].split()
    total_months = 0

    i = 0
    while i < len(components):
        if components[i].isdigit():  # Check if the component is a number
            value = int(components[i])  # Convert the number to integer
            unit = components[i + 1]  # Get the next component as the unit
            if unit == 'year' or unit == 'years':
                total_months += value * 12  # Convert years to months
            elif unit == 'month' or unit == 'months':
                total_months += value  # Add months directly
            # Skip days by advancing the index
            i += 2
        else:
            # Skip days
            i += 1

    merged_df3.at[index, 'Months_installed'] = total_months

merged_df3
# Out:
#               Team FIFA Rank  Bet365            Manager  Manager_Age  \
# 0          Albania        66   500/1           Sylvinho           50
# 1          Austria        25    66/1      Ralf Rangnick           65
# 2          Belgium         3  16.0/1   Domenico Tedesco           38
# 3          Croatia        10    40/1       Zlatko Dalic           57
# 4   Czech Republic        36   150/1         Ivan Hasek           60
# 5          Denmark        21    40/1    Kasper Hjulmand           52
# 6          England         4   3.5/1   Gareth Southgate           53
# 7           France         2   4.0/1   Didier Deschamps           55
# 8          Georgia        75   500/1       Willy Sagnol           47
# 9          Germany        16   5.5/1  Julian Nagelsmann           36
# 10         Hungary        26    80/1        Marco Rossi           59
# 11           Italy         9  14.0/1  Luciano Spalletti           65
# 12     Netherlands         7  16.0/1      Ronald Koeman           61
# 13          Poland        28   150/1    Michal Probierz           51
# 14        Portugal         6   6.5/1   Roberto Martínez           50
# 15         Romania        46   200/1  Edward Iord?nescu           45
# 16        Scotland        39   100/1       Steve Clarke           60
# 17          Serbia        33    80/1   Dragan Stojkovic           59
# 18        Slovakia        48   500/1  Francesco Calzona           55
# 19        Slovenia        57   250/1         Matjaz Kek           62
# 20           Spain         8   8.0/1  Luis de la Fuente           62
# 21     Switzerland        19    66/1        Murat Yakin           49
# 22          Turkey        40    50/1  Vincenzo Montella           49
# 23         Ukraine        22   100/1      Sergiy Rebrov           50
#
#                   Installation Contract until  Titles  Months_installed
# 0    01 year 05 months 10 days           2024     0.0                17
# 1             02 years 11 days           2025     0.0                24
# 2    01 year 04 months 04 days           2026     0.0                16
# 3   06 years 08 months 05 days           2026     0.0                80
# 4            05 months 08 days           2025     1.0                 5
# 5   03 years 10 months 11 days           2026     1.0                46
# 6   07 years 08 months 15 days           2024     0.0                92
# 7   11 years 11 months 04 days           2026     2.0               143
# 8   03 years 03 months 28 days           2024     0.0                39
# 9            08 months 21 days           2026     3.0                 8
# 10  05 years 11 months 24 days           2025     0.0                71
# 11           09 months 11 days           2026     2.0                 9
# 12   01 year 05 months 11 days           2026     1.0                17
# 13           08 months 23 days           2026     0.0                 8
# 14   01 year 05 months 03 days           2026     1.0                17
# 15  02 years 04 months 17 days           2024     0.0                28
# 16            05 years 23 days           2026     0.0                60
# 17  03 years 03 months 09 days           2026     0.0                39
# 18   01 year 11 months 03 days           2025     1.0                23
# 19  05 years 06 months 16 days           2025     0.0                66
# 20   01 year 05 months 11 days           2026     3.0                17
# 21  02 years 10 months 03 days           2024     0.0                34
# 22           08 months 22 days           2026     0.0                 8
# 23             01 year 05 days           2026     0.0                12

# %% [markdown]
# Now that the 'Installation' has been converted to the numeric months installed column it can be dropped.

# %%
#Drop Installation column
merged_df3 = merged_df3.drop(columns=['Installation'])
merged_df3
# Out:
#               Team FIFA Rank  Bet365            Manager  Manager_Age  \
# 0          Albania        66   500/1           Sylvinho           50
# 1          Austria        25    66/1      Ralf Rangnick           65
# 2          Belgium         3  16.0/1   Domenico Tedesco           38
# 3          Croatia        10    40/1       Zlatko Dalic           57
# 4   Czech Republic        36   150/1         Ivan Hasek           60
# 5          Denmark        21    40/1    Kasper Hjulmand           52
# 6          England         4   3.5/1   Gareth Southgate           53
# 7           France         2   4.0/1   Didier Deschamps           55
# 8          Georgia        75   500/1       Willy Sagnol           47
# 9          Germany        16   5.5/1  Julian Nagelsmann           36
# 10         Hungary        26    80/1        Marco Rossi           59
# 11           Italy         9  14.0/1  Luciano Spalletti           65
# 12     Netherlands         7  16.0/1      Ronald Koeman           61
# 13          Poland        28   150/1    Michal Probierz           51
# 14        Portugal         6   6.5/1   Roberto Martínez           50
# 15         Romania        46   200/1  Edward Iord?nescu           45
# 16        Scotland        39   100/1       Steve Clarke           60
# 17          Serbia        33    80/1   Dragan Stojkovic           59
# 18        Slovakia        48   500/1  Francesco Calzona           55
# 19        Slovenia        57   250/1         Matjaz Kek           62
# 20           Spain         8   8.0/1  Luis de la Fuente           62
# 21     Switzerland        19    66/1        Murat Yakin           49
# 22          Turkey        40    50/1  Vincenzo Montella           49
# 23         Ukraine        22   100/1      Sergiy Rebrov           50
#
#    Contract until  Titles  Months_installed
# 0            2024     0.0                17
# 1            2025     0.0                24
# 2            2026     0.0                16
# 3            2026     0.0                80
# 4            2025     1.0                 5
# 5            2026     1.0                46
# 6            2024     0.0                92
# 7            2026     2.0               143
# 8            2024     0.0                39
# 9            2026     3.0                 8
# 10           2025     0.0                71
# 11           2026     2.0                 9
# 12           2026     1.0                17
# 13           2026     0.0                 8
# 14           2026     1.0                17
# 15           2024     0.0                28
# 16           2026     0.0                60
# 17           2026     0.0                39
# 18           2025     1.0                23
# 19           2025     0.0                66
# 20           2026     3.0                17
# 21           2024     0.0                34
# 22           2026     0.0                 8
# 23           2026     0.0                12

# %% [markdown]
# Currently, the 'Bet365' odds column is in an unlean format. Removing the demoninator, which is consistent across all records, will turn these records from fractions to numbers which is more interpretable.

# %%
# Replace '/1' with an empty string in the 'Odds' column
merged_df3['Bet365'] = merged_df3['Bet365'].str.replace('/1', '')
# Rename the 'Odds' column to 'odds_to_one'
merged_df3 = merged_df3.rename(columns={'Bet365': 'Odds_to_One'})

# %% [markdown]
# The players dataset referring to each nations playing squad is merged.

# %%
merged_df4 = merged_df3.merge(players_grouped, on='Team', how='outer')
merged_df4
# Out:
#               Team FIFA Rank Odds_to_One            Manager  Manager_Age  \
# 0          Albania        66         500           Sylvinho           50
# 1          Austria        25          66      Ralf Rangnick           65
# 2          Belgium         3        16.0   Domenico Tedesco           38
# 3          Croatia        10          40       Zlatko Dalic           57
# 4   Czech Republic        36         150         Ivan Hasek           60
# 5          Denmark        21          40    Kasper Hjulmand           52
# 6          England         4         3.5   Gareth Southgate           53
# 7           France         2         4.0   Didier Deschamps           55
# 8          Georgia        75         500       Willy Sagnol           47
# 9          Germany        16         5.5  Julian Nagelsmann           36
# 10         Hungary        26          80        Marco Rossi           59
# 11           Italy         9        14.0  Luciano Spalletti           65
# 12     Netherlands         7        16.0      Ronald Koeman           61
# 13          Poland        28         150    Michal Probierz           51
# 14        Portugal         6         6.5   Roberto Martínez           50
# 15         Romania        46         200  Edward Iord?nescu           45
# 16        Scotland        39         100       Steve Clarke           60
# 17          Serbia        33          80   Dragan Stojkovic           59
# 18        Slovakia        48         500  Francesco Calzona           55
# 19        Slovenia        57         250         Matjaz Kek           62
# 20           Spain         8         8.0  Luis de la Fuente           62
# 21     Switzerland        19          66        Murat Yakin           49
# 22          Turkey        40          50  Vincenzo Montella           49
# 23         Ukraine        22         100      Sergiy Rebrov           50
#
#    Contract until  Titles  Months_installed        Age      Height       Caps  \
# 0            2024     0.0                17  27.307692  183.615385  26.115385
# 1            2025     0.0                24  26.807692  183.192308  23.576923
# 2            2026     0.0                16  26.880000  184.680000  37.960000
# 3            2026     0.0                80  27.692308  184.115385  44.307692
# 4            2025     1.0                 5  25.307692  185.538462  15.576923
# 5            2026     1.0                46  27.692308  186.269231  41.192308
# 6            2024     0.0                92  26.076923  182.461538  25.038462
# 7            2026     2.0               143  26.880000  184.440000  33.440000
# 8            2024     0.0                39  27.153846  184.500000  28.846154
# 9            2026     3.0                 8  28.115385  185.384615  34.846154
# 10           2025     0.0                71  27.423077  182.807692  28.846154
# 11           2026     2.0                 9  26.500000  184.346154  20.346154
# 12           2026     1.0                17  26.538462  185.192308  32.230769
# 13           2026     0.0                 8  27.555556  184.814815  30.555556
# 14           2026     1.0                17  26.961538  182.384615  42.807692
# 15           2024     0.0                28  27.000000  183.846154  22.692308
# 16           2026     0.0                60  28.230769  182.692308  24.730769
# 17           2026     0.0                39  27.384615  186.769231  33.076923
# 18           2025     1.0                23  27.269231  184.423077  33.153846
# 19           2025     0.0                66  27.346154  184.923077  29.653846
# 20           2026     3.0                17  26.961538  181.769231  20.576923
# 21           2024     0.0                34  27.692308  183.923077  42.000000
# 22           2026     0.0                 8  25.807692  183.923077  24.307692
# 23           2026     0.0                12  26.346154  184.346154  32.653846
#
#        Goals MarketValue
# 0   1.538462     4292308
# 1   3.576923     9057692
# 2   7.080000    23380000
# 3   5.653846    12603846
# 4   2.500000     7457692
# 5   5.192308    15980769
# 6   3.846154    58269231
# 7   7.680000    49360000
# 8   2.461538     6159615
# 9   5.153846    32730769
# 10  2.307692     6325000
# 11  2.269231    27134615
# 12  5.423077    32500000
# 13  5.703704     7866667
# 14  8.653846    40557692
# 15  2.423077     3543269
# 16  2.269231     7976923
# 17  4.961538    11992308
# 18  2.576923     6026923
# 19  3.000000     5365385
# 20  3.653846    37134615
# 21  4.807692    10846154
# 22  2.730769    12465385
# 23  4.384615    14576923

# %%
merged_df4 = merged_df4.round(3)
merged_df4
# Out:
#               Team FIFA Rank Odds_to_One            Manager  Manager_Age  \
# 0          Albania        66         500           Sylvinho           50
# 1          Austria        25          66      Ralf Rangnick           65
# 2          Belgium         3        16.0   Domenico Tedesco           38
# 3          Croatia        10          40       Zlatko Dalic           57
# 4   Czech Republic        36         150         Ivan Hasek           60
# 5          Denmark        21          40    Kasper Hjulmand           52
# 6          England         4         3.5   Gareth Southgate           53
# 7           France         2         4.0   Didier Deschamps           55
# 8          Georgia        75         500       Willy Sagnol           47
# 9          Germany        16         5.5  Julian Nagelsmann           36
# 10         Hungary        26          80        Marco Rossi           59
# 11           Italy         9        14.0  Luciano Spalletti           65
# 12     Netherlands         7        16.0      Ronald Koeman           61
# 13          Poland        28         150    Michal Probierz           51
# 14        Portugal         6         6.5   Roberto Martínez           50
# 15         Romania        46         200  Edward Iord?nescu           45
# 16        Scotland        39         100       Steve Clarke           60
# 17          Serbia        33          80   Dragan Stojkovic           59
# 18        Slovakia        48         500  Francesco Calzona           55
# 19        Slovenia        57         250         Matjaz Kek           62
# 20           Spain         8         8.0  Luis de la Fuente           62
# 21     Switzerland        19          66        Murat Yakin           49
# 22          Turkey        40          50  Vincenzo Montella           49
# 23         Ukraine        22         100      Sergiy Rebrov           50
#
#    Contract until  Titles  Months_installed     Age   Height    Caps  Goals  \
# 0            2024     0.0                17  27.308  183.615  26.115  1.538
# 1            2025     0.0                24  26.808  183.192  23.577  3.577
# 2            2026     0.0                16  26.880  184.680  37.960  7.080
# 3            2026     0.0                80  27.692  184.115  44.308  5.654
# 4            2025     1.0                 5  25.308  185.538  15.577  2.500
# 5            2026     1.0                46  27.692  186.269  41.192  5.192
# 6            2024     0.0                92  26.077  182.462  25.038  3.846
# 7            2026     2.0               143  26.880  184.440  33.440  7.680
# 8            2024     0.0                39  27.154  184.500  28.846  2.462
# 9            2026     3.0                 8  28.115  185.385  34.846  5.154
# 10           2025     0.0                71  27.423  182.808  28.846  2.308
# 11           2026     2.0                 9  26.500  184.346  20.346  2.269
# 12           2026     1.0                17  26.538  185.192  32.231  5.423
# 13           2026     0.0                 8  27.556  184.815  30.556  5.704
# 14           2026     1.0                17  26.962  182.385  42.808  8.654
# 15           2024     0.0                28  27.000  183.846  22.692  2.423
# 16           2026     0.0                60  28.231  182.692  24.731  2.269
# 17           2026     0.0                39  27.385  186.769  33.077  4.962
# 18           2025     1.0                23  27.269  184.423  33.154  2.577
# 19           2025     0.0                66  27.346  184.923  29.654  3.000
# 20           2026     3.0                17  26.962  181.769  20.577  3.654
# 21           2024     0.0                34  27.692  183.923  42.000  4.808
# 22           2026     0.0                 8  25.808  183.923  24.308  2.731
# 23           2026     0.0                12  26.346  184.346  32.654  4.385
#
#    MarketValue
# 0      4292308
# 1      9057692
# 2     23380000
# 3     12603846
# 4      7457692
# 5     15980769
# 6     58269231
# 7     49360000
# 8      6159615
# 9     32730769
# 10     6325000
# 11    27134615
# 12    32500000
# 13     7866667
# 14    40557692
# 15     3543269
# 16     7976923
# 17    11992308
# 18     6026923
# 19     5365385
# 20    37134615
# 21    10846154
# 22    12465385
# 23    14576923

# %% [markdown]
# Each teams win percentage since the last tournament is merged to the dataframe. This value represents their ability to win games over the last 3 years (2021-2024).

# %%
merged_df5 = merged_df4.merge(teams_stats, on='Team', how='outer')
merged_df5
# Out:
#               Team FIFA Rank Odds_to_One            Manager  Manager_Age  \
# 0          Albania        66         500           Sylvinho           50
# 1          Austria        25          66      Ralf Rangnick           65
# 2          Belgium         3        16.0   Domenico Tedesco           38
# 3          Croatia        10          40       Zlatko Dalic           57
# 4   Czech Republic        36         150         Ivan Hasek           60
# 5          Denmark        21          40    Kasper Hjulmand           52
# 6          England         4         3.5   Gareth Southgate           53
# 7           France         2         4.0   Didier Deschamps           55
# 8          Georgia        75         500       Willy Sagnol           47
# 9          Germany        16         5.5  Julian Nagelsmann           36
# 10         Hungary        26          80        Marco Rossi           59
# 11           Italy         9        14.0  Luciano Spalletti           65
# 12     Netherlands         7        16.0      Ronald Koeman           61
# 13          Poland        28         150    Michal Probierz           51
# 14        Portugal         6         6.5   Roberto Martínez           50
# 15         Romania        46         200  Edward Iord?nescu           45
# 16        Scotland        39         100       Steve Clarke           60
# 17          Serbia        33          80   Dragan Stojkovic           59
# 18        Slovakia        48         500  Francesco Calzona           55
# 19        Slovenia        57         250         Matjaz Kek           62
# 20           Spain         8         8.0  Luis de la Fuente           62
# 21     Switzerland        19          66        Murat Yakin           49
# 22          Turkey        40          50  Vincenzo Montella           49
# 23         Ukraine        22         100      Sergiy Rebrov           50
#
#    Contract until  Titles  Months_installed     Age   Height    Caps  Goals  \
# 0            2024     0.0                17  27.308  183.615  26.115  1.538
# 1            2025     0.0                24  26.808  183.192  23.577  3.577
# 2            2026     0.0                16  26.880  184.680  37.960  7.080
# 3            2026     0.0                80  27.692  184.115  44.308  5.654
# 4            2025     1.0                 5  25.308  185.538  15.577  2.500
# 5            2026     1.0                46  27.692  186.269  41.192  5.192
# 6            2024     0.0                92  26.077  182.462  25.038  3.846
# 7            2026     2.0               143  26.880  184.440  33.440  7.680
# 8            2024     0.0                39  27.154  184.500  28.846  2.462
# 9            2026     3.0                 8  28.115  185.385  34.846  5.154
# 10           2025     0.0                71  27.423  182.808  28.846  2.308
# 11           2026     2.0                 9  26.500  184.346  20.346  2.269
# 12           2026     1.0                17  26.538  185.192  32.231  5.423
# 13           2026     0.0                 8  27.556  184.815  30.556  5.704
# 14           2026     1.0                17  26.962  182.385  42.808  8.654
# 15           2024     0.0                28  27.000  183.846  22.692  2.423
# 16           2026     0.0                60  28.231  182.692  24.731  2.269
# 17           2026     0.0                39  27.385  186.769  33.077  4.962
# 18           2025     1.0                23  27.269  184.423  33.154  2.577
# 19           2025     0.0                66  27.346  184.923  29.654  3.000
# 20           2026     3.0                17  26.962  181.769  20.577  3.654
# 21           2024     0.0                34  27.692  183.923  42.000  4.808
# 22           2026     0.0                 8  25.808  183.923  24.308  2.731
# 23           2026     0.0                12  26.346  184.346  32.654  4.385
#
#    MarketValue  Win Percentage
# 0      4292308       38.709677
# 1      9057692       54.838710
# 2     23380000       57.575758
# 3     12603846       59.459459
# 4      7457692       48.387097
# 5     15980769       65.625000
# 6     58269231       55.882353
# 7     49360000       63.888889
# 8      6159615       51.724138
# 9     32730769       50.000000
# 10     6325000       54.838710
# 11    27134615       46.875000
# 12    32500000       67.647059
# 13     7866667       52.941176
# 14    40557692       75.000000
# 15     3543269       41.935484
# 16     7976923       51.612903
# 17    11992308       60.606061
# 18     6026923       45.161290
# 19     5365385       50.000000
# 20    37134615       64.705882
# 21    10846154       44.117647
# 22    12465385       51.612903
# 23    14576923       44.827586

# %% [markdown]
# Each teams qualifying record is added to the dataframe. This data represent each teams performance in qualifying in detail.

# %%
merged_df6 = merged_df5.merge(quali_sorted_filtered, on='Team', how='outer')
merged_df6
# Out:
#               Team FIFA Rank Odds_to_One            Manager  Manager_Age  \
# 0          Albania        66         500           Sylvinho           50
# 1          Austria        25          66      Ralf Rangnick           65
# 2          Belgium         3        16.0   Domenico Tedesco           38
# 3          Croatia        10          40       Zlatko Dalic           57
# 4   Czech Republic        36         150         Ivan Hasek           60
# 5          Denmark        21          40    Kasper Hjulmand           52
# 6          England         4         3.5   Gareth Southgate           53
# 7           France         2         4.0   Didier Deschamps           55
# 8          Georgia        75         500       Willy Sagnol           47
# 9          Germany        16         5.5  Julian Nagelsmann           36
# 10         Hungary        26          80        Marco Rossi           59
# 11           Italy         9        14.0  Luciano Spalletti           65
# 12     Netherlands         7        16.0      Ronald Koeman           61
# 13          Poland        28         150    Michal Probierz           51
# 14        Portugal         6         6.5   Roberto Martínez           50
# 15         Romania        46         200  Edward Iord?nescu           45
# 16        Scotland        39         100       Steve Clarke           60
# 17          Serbia        33          80   Dragan Stojkovic           59
# 18        Slovakia        48         500  Francesco Calzona           55
# 19        Slovenia        57         250         Matjaz Kek           62
# 20           Spain         8         8.0  Luis de la Fuente           62
# 21     Switzerland        19          66        Murat Yakin           49
# 22          Turkey        40          50  Vincenzo Montella           49
# 23         Ukraine        22         100      Sergiy Rebrov           50
#
#    Contract until  Titles  Months_installed     Age   Height    Caps  Goals  \
# 0            2024     0.0                17  27.308  183.615  26.115  1.538
# 1            2025     0.0                24  26.808  183.192  23.577  3.577
# 2            2026     0.0                16  26.880  184.680  37.960  7.080
# 3            2026     0.0                80  27.692  184.115  44.308  5.654
# 4            2025     1.0                 5  25.308  185.538  15.577  2.500
# 5            2026     1.0                46  27.692  186.269  41.192  5.192
# 6            2024     0.0                92  26.077  182.462  25.038  3.846
# 7            2026     2.0               143  26.880  184.440  33.440  7.680
# 8            2024     0.0                39  27.154  184.500  28.846  2.462
# 9            2026     3.0                 8  28.115  185.385  34.846  5.154
# 10           2025     0.0                71  27.423  182.808  28.846  2.308
# 11           2026     2.0                 9  26.500  184.346  20.346  2.269
# 12           2026     1.0                17  26.538  185.192  32.231  5.423
# 13           2026     0.0                 8  27.556  184.815  30.556  5.704
# 14           2026     1.0                17  26.962  182.385  42.808  8.654
# 15           2024     0.0                28  27.000  183.846  22.692  2.423
# 16           2026     0.0                60  28.231  182.692  24.731  2.269
# 17           2026     0.0                39  27.385  186.769  33.077  4.962
# 18           2025     1.0                23  27.269  184.423  33.154  2.577
# 19           2025     0.0                66  27.346  184.923  29.654  3.000
# 20           2026     3.0                17  26.962  181.769  20.577  3.654
# 21           2024     0.0                34  27.692  183.923  42.000  4.808
# 22           2026     0.0                 8  25.808  183.923  24.308  2.731
# 23           2026     0.0                12  26.346  184.346  32.654  4.385
#
#    MarketValue  Win Percentage  Q_GF  Q_GA  Q_GD  Q_PPG_Last_5 Q_Clean_Sheets  \
# 0      4292308       38.709677  12.0   4.0   8.0          1.88            50%
# 1      9057692       54.838710  17.0   7.0  10.0          2.38            38%
# 2     23380000       57.575758  22.0   4.0  18.0          2.50            63%
# 3     12603846       59.459459  13.0   4.0   9.0          2.00            63%
# 4      7457692       48.387097  12.0   6.0   6.0          1.88            50%
# 5     15980769       65.625000  19.0  10.0   9.0          2.20            30%
# 6     58269231       55.882353  22.0   4.0  18.0          2.50            50%
# 7     49360000       63.888889  29.0   3.0  26.0          2.75            75%
# 8      6159615       51.724138  14.0  18.0  -4.0          1.20            30%
# 9     32730769       50.000000   NaN   NaN   NaN           NaN            NaN
# 10     6325000       54.838710  16.0   7.0   9.0          2.25            38%
# 11    27134615       46.875000  16.0   9.0   7.0          1.75            38%
# 12    32500000       67.647059  17.0   7.0  10.0          2.25            63%
# 13     7866667       52.941176  15.0  11.0   4.0          1.50            40%
# 14    40557692       75.000000  36.0   2.0  34.0          3.00            90%
# 15     3543269       41.935484  16.0   5.0  11.0          2.20            60%
# 16     7976923       51.612903  17.0   8.0   9.0          2.13            50%
# 17    11992308       60.606061  15.0   9.0   6.0          1.75            25%
# 18     6026923       45.161290  17.0   8.0   9.0          2.20            50%
# 19     5365385       50.000000  20.0   9.0  11.0          2.20            40%
# 20    37134615       64.705882  25.0   5.0  20.0          2.63            50%
# 21    10846154       44.117647  22.0  11.0  11.0          1.70            30%
# 22    12465385       51.612903  14.0   7.0   7.0          2.13            38%
# 23    14576923       44.827586  15.0  10.0   5.0          2.00            30%
#
#     Q_xGF
# 0    1.13
# 1    1.91
# 2    1.73
# 3    2.23
# 4    1.83
# 5    1.90
# 6    1.56
# 7    2.57
# 8    1.00
# 9     NaN
# 10   1.67
# 11   1.66
# 12   2.01
# 13   1.73
# 14   2.46
# 15   1.55
# 16   1.16
# 17   1.68
# 18   1.37
# 19   1.41
# 20   2.29
# 21   2.16
# 22   1.79
# 23   1.21

# %% [markdown]
# #Final dataset

# %% [markdown]
# Once data from all sources has been collected it is ready for further exploration and analysis.
#
# To summarise the new dataset has information regarding:
#
#
#
# 1.   Nation (Team)
# 2.   Nation Ranking (FIFA Rank)
# 3.   Tournament Odds (Odds_to_One)
# 4.   Manager Statistics (Manager, Manager_Age, Contract until, Months_installed)
# 5.   Nation Tournament Wins (Titles)
# 6.   Playing Squad Data (Age, Height, Caps, Goals, MarketValue, Win Percentage)
# 7.   Qualifying Team Data (Q_GF, Q_GA, Q_PPG_Last_5, Q_Clean_Sheets, Q_xGF)

# %%
final_data = merged_df6
final_data
# Out:
#               Team FIFA Rank Odds_to_One            Manager  Manager_Age  \
# 0          Albania        66         500           Sylvinho           50
# 1          Austria        25          66      Ralf Rangnick           65
# 2          Belgium         3        16.0   Domenico Tedesco           38
# 3          Croatia        10          40       Zlatko Dalic           57
# 4   Czech Republic        36         150         Ivan Hasek           60
# 5          Denmark        21          40    Kasper Hjulmand           52
# 6          England         4         3.5   Gareth Southgate           53
# 7           France         2         4.0   Didier Deschamps           55
# 8          Georgia        75         500       Willy Sagnol           47
# 9          Germany        16         5.5  Julian Nagelsmann           36
# 10         Hungary        26          80        Marco Rossi           59
# 11           Italy         9        14.0  Luciano Spalletti           65
# 12     Netherlands         7        16.0      Ronald Koeman           61
# 13          Poland        28         150    Michal Probierz           51
# 14        Portugal         6         6.5   Roberto Martínez           50
# 15         Romania        46         200  Edward Iord?nescu           45
# 16        Scotland        39         100       Steve Clarke           60
# 17          Serbia        33          80   Dragan Stojkovic           59
# 18        Slovakia        48         500  Francesco Calzona           55
# 19        Slovenia        57         250         Matjaz Kek           62
# 20           Spain         8         8.0  Luis de la Fuente           62
# 21     Switzerland        19          66        Murat Yakin           49
# 22          Turkey        40          50  Vincenzo Montella           49
# 23         Ukraine        22         100      Sergiy Rebrov           50
#
#    Contract until  Titles  Months_installed     Age   Height    Caps  Goals  \
# 0            2024     0.0                17  27.308  183.615  26.115  1.538
# 1            2025     0.0                24  26.808  183.192  23.577  3.577
# 2            2026     0.0                16  26.880  184.680  37.960  7.080
# 3            2026     0.0                80  27.692  184.115  44.308  5.654
# 4            2025     1.0                 5  25.308  185.538  15.577  2.500
# 5            2026     1.0                46  27.692  186.269  41.192  5.192
# 6            2024     0.0                92  26.077  182.462  25.038  3.846
# 7            2026     2.0               143  26.880  184.440  33.440  7.680
# 8            2024     0.0                39  27.154  184.500  28.846  2.462
# 9            2026     3.0                 8  28.115  185.385  34.846  5.154
# 10           2025     0.0                71  27.423  182.808  28.846  2.308
# 11           2026     2.0                 9  26.500  184.346  20.346  2.269
# 12           2026     1.0                17  26.538  185.192  32.231  5.423
# 13           2026     0.0                 8  27.556  184.815  30.556  5.704
# 14           2026     1.0                17  26.962  182.385  42.808  8.654
# 15           2024     0.0                28  27.000  183.846  22.692  2.423
# 16           2026     0.0                60  28.231  182.692  24.731  2.269
# 17           2026     0.0                39  27.385  186.769  33.077  4.962
# 18           2025     1.0                23  27.269  184.423  33.154  2.577
# 19           2025     0.0                66  27.346  184.923  29.654  3.000
# 20           2026     3.0                17  26.962  181.769  20.577  3.654
# 21           2024     0.0                34  27.692  183.923  42.000  4.808
# 22           2026     0.0                 8  25.808  183.923  24.308  2.731
# 23           2026     0.0                12  26.346  184.346  32.654  4.385
#
#    MarketValue  Win Percentage  Q_GF  Q_GA  Q_GD  Q_PPG_Last_5 Q_Clean_Sheets  \
# 0      4292308       38.709677  12.0   4.0   8.0          1.88            50%
# 1      9057692       54.838710  17.0   7.0  10.0          2.38            38%
# 2     23380000       57.575758  22.0   4.0  18.0          2.50            63%
# 3     12603846       59.459459  13.0   4.0   9.0          2.00            63%
# 4      7457692       48.387097  12.0   6.0   6.0          1.88            50%
# 5     15980769       65.625000  19.0  10.0   9.0          2.20            30%
# 6     58269231       55.882353  22.0   4.0  18.0          2.50            50%
# 7     49360000       63.888889  29.0   3.0  26.0          2.75            75%
# 8      6159615       51.724138  14.0  18.0  -4.0          1.20            30%
# 9     32730769       50.000000   NaN   NaN   NaN           NaN            NaN
# 10     6325000       54.838710  16.0   7.0   9.0          2.25            38%
# 11    27134615       46.875000  16.0   9.0   7.0          1.75            38%
# 12    32500000       67.647059  17.0   7.0  10.0          2.25            63%
# 13     7866667       52.941176  15.0  11.0   4.0          1.50            40%
# 14    40557692       75.000000  36.0   2.0  34.0          3.00            90%
# 15     3543269       41.935484  16.0   5.0  11.0          2.20            60%
# 16     7976923       51.612903  17.0   8.0   9.0          2.13            50%
# 17    11992308       60.606061  15.0   9.0   6.0          1.75            25%
# 18     6026923       45.161290  17.0   8.0   9.0          2.20            50%
# 19     5365385       50.000000  20.0   9.0  11.0          2.20            40%
# 20    37134615       64.705882  25.0   5.0  20.0          2.63            50%
# 21    10846154       44.117647  22.0  11.0  11.0          1.70            30%
# 22    12465385       51.612903  14.0   7.0   7.0          2.13            38%
# 23    14576923       44.827586  15.0  10.0   5.0          2.00            30%
#
#     Q_xGF
# 0    1.13
# 1    1.91
# 2    1.73
# 3    2.23
# 4    1.83
# 5    1.90
# 6    1.56
# 7    2.57
# 8    1.00
# 9     NaN
# 10   1.67
# 11   1.66
# 12   2.01
# 13   1.73
# 14   2.46
# 15   1.55
# 16   1.16
# 17   1.68
# 18   1.37
# 19   1.41
# 20   2.29
# 21   2.16
# 22   1.79
# 23   1.21

# %% [markdown]
# Germany has NaNs refeerring to their qualifying record because they are the host nation and therefore do not have to qualify

# %%
final_data.to_csv('euros_data.csv', index=False)
